# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Exponente que indica la cantidad de puntos del set P
# Es para el label más que nada
# Y para el nombre del archivo ahora
n = 14
totalPuntos = 2**n

# Para el método CP
fileNameCP = 'experimento_CP_' + str(n) + '.tsv'
dfCP = pd.read_csv(fileNameCP, sep = '\t')
# display(dfCP)

# Para el método SS
fileNameSS = 'experimento_SS_' + str(n) + '.tsv'
dfSS = pd.read_csv(fileNameSS, sep = '\t')

# El eje X son los accesos
# El eje Y el conteo de esos accesos
iosDataCP = dfCP['ios'].values
iosDataSS = dfSS['ios'].values

# Datos para CP
promedioCP = iosDataCP.mean()
stdCP = iosDataCP.std()
intervaloConfianzaCP = 1.96 * (promedioCP / np.sqrt(len(iosDataCP)))
dfCP['% del conjunto'] = (dfCP['size'] / totalPuntos)*100

# Datos para SS
promedioSS = iosDataSS.mean()
stdSS = iosDataSS.std()
intervaloConfianzaSS = 1.96 * (promedioSS / np.sqrt(len(iosDataSS)))
dfSS['% del conjunto'] = (dfSS['size'] / totalPuntos)*100

# Printeo de datos
print(" ")
print("Datos del método CP -------------------------------------------------")
print("Promedio CP: " + str(promedioCP))
print("Desviación estándar CP: " + str(stdCP))
print("Intervalo de Confianza al 95%: " + str(intervaloConfianzaCP))
print("Promedio del % del conjunto de puntos como respuesta a la búsqueda: " + str(dfCP['% del conjunto'].mean()))
print(" ")
print("Datos del método SS -------------------------------------------------")
print("Promedio SS: " + str(promedioSS))
print("Desviación estándar SS: " + str(stdSS))
print("Intervalo de Confianza al 95%: " + str(intervaloConfianzaSS))
print("Promedio del % del conjunto de puntos como respuesta a la búsqueda: " + str(dfSS['% del conjunto'].mean()))
print(" ")

# Se arman los histogramas a partir de los datos que supuestamente ya tenemos
# bins: cantidad de "contenedores" para dividir los datos
# density: normalizar la altura de cada contenedor (influirá si ambos trabajan con 100 datos?)
# alpha: transparencia/opacidad de las barras
plt.hist(iosDataCP, bins=10, density=False, alpha=0.5, color='r', label='Método CP')
plt.hist(iosDataSS, bins=10, density=False, alpha=0.5, color='b', label='Método SS')

# Labels
plt.xlabel('Cantidad de accesos')
plt.ylabel('Frecuencia')
plt.title('Distribución de accesos para 2^' + str(n) + ' puntos')
plt.legend()

# Mostrar el histograma
plt.show()
# Out:
#
# Datos del método CP -------------------------------------------------
# Promedio CP: 12.0
# Desviación estándar CP: 2.08806130178211
# Intervalo de Confianza al 95%: 2.352
# Promedio del % del conjunto de puntos como respuesta a la búsqueda: 0.126953125
#
# Datos del método SS -------------------------------------------------
# Promedio SS: 22.24
# Desviación estándar SS: 5.140272366324571
# Intervalo de Confianza al 95%: 4.359039999999999
# Promedio del % del conjunto de puntos como respuesta a la búsqueda: 0.126953125

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Exponente que indica la cantidad de puntos del set P
# Es para el label más que nada
# Y para el nombre del archivo ahora
n = 22
totalPuntos = 2**n

# Para el método CP
fileNameCP = 'experimento_CP_' + str(n) + '.tsv'
dfCP = pd.read_csv(fileNameCP, sep = '\t')
# display(dfCP)


# El eje X son los accesos
# El eje Y el conteo de esos accesos
iosDataCP = dfCP['ios'].values

# Datos para CP
promedioCP = iosDataCP.mean()
stdCP = iosDataCP.std()
intervaloConfianzaCP = 1.96 * (promedioCP / np.sqrt(len(iosDataCP)))
dfCP['% del conjunto'] = (dfCP['size'] / totalPuntos)*100

# Printeo de datos
print(" ")
print("Datos del método CP -------------------------------------------------")
print("Promedio CP: " + str(promedioCP))
print("Desviación estándar CP: " + str(stdCP))
print("Intervalo de Confianza al 95%: " + str(intervaloConfianzaCP))
print("Promedio del % del conjunto de puntos como respuesta a la búsqueda: " + str(dfCP['% del conjunto'].mean()))
print(" ")

# Se arman los histogramas a partir de los datos que supuestamente ya tenemos
# bins: cantidad de "contenedores" para dividir los datos
# density: normalizar la altura de cada contenedor (influirá si ambos trabajan con 100 datos?)
# alpha: transparencia/opacidad de las barras
plt.hist(iosDataCP, bins=10, density=False, alpha=0.5, color='r', label='Método CP')

# Labels
plt.xlabel('Cantidad de accesos')
plt.ylabel('Frecuencia')
plt.title('Distribución de accesos para 2^' + str(n) + ' puntos')
plt.legend()

# Mostrar el histograma
plt.show()
# Out:
#
# Datos del método CP -------------------------------------------------
# Promedio CP: 35.77
# Desviación estándar CP: 17.274753254388322
# Intervalo de Confianza al 95%: 7.0109200000000005
# Promedio del % del conjunto de puntos como respuesta a la búsqueda: 0.00880885124206543

# %% [markdown]
# ## Ephy

# %%
# prompt:  Descomprimir Zip

# !unzip -j experiments_cp.zip
# Out:
# Archive:  experiments_cp.zip
#   inflating: creation_CP_10.txt
#   inflating: creation_CP_11.txt
#   inflating: creation_CP_12.txt
#   inflating: creation_CP_13.txt
#   inflating: creation_CP_14.txt
#   inflating: creation_CP_15.txt
#   inflating: creation_CP_16.txt
#   inflating: creation_CP_17.txt
#   inflating: creation_CP_18.txt
#   inflating: creation_CP_19.txt
#   inflating: creation_CP_20.txt
#   inflating: creation_CP_21.txt
#   inflating: creation_CP_22.txt
#   inflating: experimento_CP_10.tsv
#   inflating: experimento_CP_11.tsv
#   inflating: experimento_CP_12.tsv
#   inflating: experimento_CP_13.tsv
#   inflating: experimento_CP_14.tsv
#   inflating: experimento_CP_15.tsv
#   inflating: experimento_CP_16.tsv
#   inflating: experimento_CP_17.tsv
#   inflating: experimento_CP_18.tsv
#   inflating: experimento_CP_19.tsv
#   inflating: experimento_CP_20.tsv
#   inflating: experimento_CP_21.tsv
#   inflating: experimento_CP_22.tsv

# %%
# !unzip -j experiments_ss.zip
# Out:
# Archive:  experiments_ss.zip
#   inflating: creation_SS_10.txt
#   inflating: creation_SS_11.txt
#   inflating: creation_SS_12.txt
#   inflating: creation_SS_13.txt
#   inflating: creation_SS_14.txt
#   inflating: experimento_SS_10.tsv
#   inflating: experimento_SS_11.tsv
#   inflating: experimento_SS_12.tsv
#   inflating: experimento_SS_13.tsv
#   inflating: experimento_SS_14.tsv

# %%
# Leo los TST

dim = []
muCP = []
stdCP = []
for n in range(10, 23):
    # Para el método CP
    fileNameCP = 'experimento_CP_' + str(n) + '.tsv'
    dfCP = pd.read_csv(fileNameCP, sep = '\t')
    # Obtengo los accesos
    iosDataCP = dfCP['ios'].values
    promedioCP = iosDataCP.mean()
    std = iosDataCP.std()

    dim.append(n)
    muCP.append(promedioCP)
    stdCP.append(std)

d = {"dim": dim, "muCP": muCP, "stdCP": stdCP }
dfCP = pd.DataFrame(data=d)

# %%
dimSS = []
muSS = []
stdSS = []
for n in range(10, 15):
    # Para el método SS
    fileNameSS = 'experimento_SS_' + str(n) + '.tsv'
    dfSS = pd.read_csv(fileNameSS, sep = '\t')
    # Obtengo los accesos
    iosDataSS = dfSS['ios'].values
    promedioSS = iosDataSS.mean()
    std = iosDataSS.std()

    dimSS.append(n)
    muSS.append(promedioSS)
    stdSS.append(std)

d = {"dim": dimSS, "muSS": muSS, "stdSS": stdSS }
dfSS = pd.DataFrame(data=d)

# %%
dfSS
# Out:
#    dim   muSS     stdSS
# 0   10   8.60  1.969772
# 1   11  11.40  2.831960
# 2   12  12.85  2.974475
# 3   13  18.49  4.655094
# 4   14  22.24  5.140272

# %%
# @title dim vs muCP

# Graficando los puntos de dispersión
plt.scatter(dfCP['dim'], dfCP['muCP'], s=16, alpha=0.8, label="CP Method")
# Agregando líneas verticales correspondientes a la desviación estándar
plt.errorbar(dfCP['dim'], dfCP['muCP'], yerr=dfCP['stdCP'], fmt='x-', color='gray', alpha=0.6, capsize=4)

# Graficando los puntos de dispersión para dfSS
plt.scatter(dfSS['dim'], dfSS['muSS'], s=16, alpha=0.8, color='red', label="SS Method")  # Cambia el color si lo deseas
# Agregando líneas verticales correspondientes a la desviación estándar para dfSS
plt.errorbar(dfSS['dim'], dfSS['muSS'], yerr=dfSS['stdSS'], fmt='x-', color='gray', alpha=0.6, capsize=4)  # Puedes cambiar el color


# Etiquetando los ejes
plt.xlabel('Dim')
plt.ylabel('Promedio de I/Os (100 consultas)')
# Agregando la leyenda
plt.legend()

plt.show()
